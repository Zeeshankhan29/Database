# %%
import pandas as pd

# %%
p={ "firstName": "Joe",
   "lastName": "Jackson",
   "gender": "male",
   "age": 28,
   "address": [
       "streetAddress", "101",
       "city", "San Diego",
       "state",'dd'
       ],
   "phoneNumbers": [
     "type", "home", "number","7349282382" ,'87','96'
   ]
}

# %%
p
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': 28,
#  'address': ['streetAddress', '101', 'city', 'San Diego', 'state', 'dd'],
#  'phoneNumbers': ['type', 'home', 'number', '7349282382', '87', '96']}

# %%
type(p)
# Out:
# dict

# %%
df=pd.DataFrame(p)

# %%
df
# Out:
#   firstName lastName gender  age        address phoneNumbers
# 0       Joe  Jackson   male   28  streetAddress         type
# 1       Joe  Jackson   male   28            101         home
# 2       Joe  Jackson   male   28           city       number
# 3       Joe  Jackson   male   28      San Diego   7349282382
# 4       Joe  Jackson   male   28          state           87
# 5       Joe  Jackson   male   28             dd           96

# %%
o="""{ "firstName": "Joe",
   "lastName": "Jackson",
   "gender": "male",
   "age": "28",
   "address": [
       "streetAddress", "101",
       "city", "San Diego",
       "state","dd"
       ],
   "phoneNumbers": [
     "type", "home", "number","7349282382" ,"87","96"
   ]
}"""

# %%
o
# Out:
# '{ "firstName": "Joe",\n   "lastName": "Jackson",\n   "gender": "male",\n   "age": "28",\n   "address": [\n       "streetAddress", "101",\n       "city", "San Diego",\n       "state","dd"\n       ],\n   "phoneNumbers": [\n     "type", "home", "number","7349282382" ,"87","96"\n   ]\n}'

# %%
type(o)
# Out:
# str

# %%
o
# Out:
# '{ "firstName": "Joe",\n   "lastName": "Jackson",\n   "gender": "male",\n   "age": "28",\n   "address": [\n       "streetAddress", "101",\n       "city", "San Diego",\n       "state","dd"\n       ],\n   "phoneNumbers": [\n     "type", "home", "number","7349282382" ,"87","96"\n   ]\n}'

# %%
type(o)
# Out:
# str

# %%
json.loads(o)
# Out:
# {'key': 256}

# %%
o='''{
    
    "key":256
}'''

# %%
o='{"sepal_length":{"0":5.1,"1":4.9,"2":4.7,"3":4.6,"4":5.0,"5":5.4,"6":4.6,"7":5.0,"8":4.4,"9":4.9,"10":5.4,"11":4.8,"12":4.8,"13":4.3,"14":5.8,"15":5.7,"16":5.4,"17":5.1,"18":5.7,"19":5.1,"20":5.4,"21":5.1,"22":4.6,"23":5.1,"24":4.8,"25":5.0,"26":5.0,"27":5.2,"28":5.2,"29":4.7,"30":4.8,"31":5.4,"32":5.2,"33":5.5,"34":4.9,"35":5.0,"36":5.5,"37":4.9,"38":4.4,"39":5.1,"40":5.0,"41":4.5,"42":4.4,"43":5.0,"44":5.1,"45":4.8,"46":5.1,"47":4.6,"48":5.3,"49":5.0,"50":7.0,"51":6.4,"52":6.9,"53":5.5,"54":6.5,"55":5.7,"56":6.3,"57":4.9,"58":6.6,"59":5.2,"60":5.0,"61":5.9,"62":6.0,"63":6.1,"64":5.6,"65":6.7,"66":5.6,"67":5.8,"68":6.2,"69":5.6,"70":5.9,"71":6.1,"72":6.3,"73":6.1,"74":6.4,"75":6.6,"76":6.8,"77":6.7,"78":6.0,"79":5.7,"80":5.5,"81":5.5,"82":5.8,"83":6.0,"84":5.4,"85":6.0,"86":6.7,"87":6.3,"88":5.6,"89":5.5,"90":5.5,"91":6.1,"92":5.8,"93":5.0,"94":5.6,"95":5.7,"96":5.7,"97":6.2,"98":5.1,"99":5.7,"100":6.3,"101":5.8,"102":7.1,"103":6.3,"104":6.5,"105":7.6,"106":4.9,"107":7.3,"108":6.7,"109":7.2,"110":6.5,"111":6.4,"112":6.8,"113":5.7,"114":5.8,"115":6.4,"116":6.5,"117":7.7,"118":7.7,"119":6.0,"120":6.9,"121":5.6,"122":7.7,"123":6.3,"124":6.7,"125":7.2,"126":6.2,"127":6.1,"128":6.4,"129":7.2,"130":7.4,"131":7.9,"132":6.4,"133":6.3,"134":6.1,"135":7.7,"136":6.3,"137":6.4,"138":6.0,"139":6.9,"140":6.7,"141":6.9,"142":5.8,"143":6.8,"144":6.7,"145":6.7,"146":6.3,"147":6.5,"148":6.2,"149
130":1.9,"131":2.0,"132":2.2,"133":1.5,"134":1.4,"135":2.3,"136":2.4,"137":1.8,"138":1.8,"139":2.1,"140":2.4,"141":2.3,"142":1.9,"143":2.3,"144":2.5,"145":2.3,"146":1.9,"147":2.0,"148":2.3,"149":1.8},"species":{"0":"setosa","1":"setosa","2":"setosa","3":"setosa","4":"setosa","5":"setosa","6":"setosa","7":"setosa","8":"setosa","9":"setosa","10":"setosa","11":"setosa","12":"setosa","13":"setosa","14":"setosa","15":"setosa","16":"setosa","17":"setosa","18":"setosa","19":"setosa","20":"setosa","21":"setosa","22":"setosa","23":"setosa","24":"setosa","25":"setosa","26":"setosa","27":"setosa","28":"setosa","29":"setosa","30":"setosa","31":"setosa","32":"setosa","33":"setosa","34":"setosa","35":"setosa","36":"setosa","37":"setosa","38":"setosa","39":"setosa","40":"setosa","41":"setosa","42":"setosa","43":"setosa","44":"setosa","45":"setosa","46":"setosa","47":"setosa","48":"setosa","49":"setosa","50":"versicolor","51":"versicolor","52":"versicolor","53":"versicolor","54":"versicolor","55":"versicolor","56":"versicolor","57":"versicolor","58":"versicolor","59":"versicolor","60":"versicolor","61":"versicolor","62":"versicolor","63":"versicolor","64":"versicolor","65":"versicolor","66":"versicolor","67":"versicolor","68":"versicolor","69":"versicolor","70":"versicolor","71":"versicolor","72":"versicolor","73":"versicolor","74":"versicolor","75":"versicolor","76":"versicolor","77":"versicolor","78":"versicolor","79":"versicolor","80":"versicolor","81":"versicolor","82":"versicolor","83":"versicolor","84":"versicolor","85":"versicolor","86":"versicolor","87":"versicolor","88":"versicolor","89":"versicolor","90":"versicolor","91":"versicolor","92":"versicolor","93":"versicolor","94":"versicolor","95":"versicolor","96":"versicolor","97":"versicolor","98":"versicolor","99":"versicolor","100":"virginica","101":"virginica","102":"virginica","103":"virginica","104":"virginica","105":"virginica","106":"virginica","107":"virginica","108":"virginica","109":"virginica","110":"virginica","111":"virginica","112":"virginica","113":"virginica","114":"virginica","115":"virginica","116":"virginica","117":"virginica","118":"virginica","119":"virginica","120":"virginica","121":"virginica","122":"virginica","123":"virginica","124":"virginica","125":"virginica","126":"virginica","127":"virginica","128":"virginica","129":"virginica","130":"virginica","131":"virginica","132":"virginica","133":"virginica","134":"virginica","135":"virginica","136":"virginica","137":"virginica","138":"virginica","139":"virginica","140":"virginica","141":"virginica","142":"virginica","143":"virginica","144":"virginica","145":"virginica","146":"virginica","147":"virginica","148":"virginica","149":"virginica"}}'

# %%
o
# Out:
# '{"sepal_length":{"0":5.1,"1":4.9,"2":4.7,"3":4.6,"4":5.0,"5":5.4,"6":4.6,"7":5.0,"8":4.4,"9":4.9,"10":5.4,"11":4.8,"12":4.8,"13":4.3,"14":5.8,"15":5.7,"16":5.4,"17":5.1,"18":5.7,"19":5.1,"20":5.4,"21":5.1,"22":4.6,"23":5.1,"24":4.8,"25":5.0,"26":5.0,"27":5.2,"28":5.2,"29":4.7,"30":4.8,"31":5.4,"32":5.2,"33":5.5,"34":4.9,"35":5.0,"36":5.5,"37":4.9,"38":4.4,"39":5.1,"40":5.0,"41":4.5,"42":4.4,"43":5.0,"44":5.1,"45":4.8,"46":5.1,"47":4.6,"48":5.3,"49":5.0,"50":7.0,"51":6.4,"52":6.9,"53":5.5,"54":6.5,"55":5.7,"56":6.3,"57":4.9,"58":6.6,"59":5.2,"60":5.0,"61":5.9,"62":6.0,"63":6.1,"64":5.6,"65":6.7,"66":5.6,"67":5.8,"68":6.2,"69":5.6,"70":5.9,"71":6.1,"72":6.3,"73":6.1,"74":6.4,"75":6.6,"76":6.8,"77":6.7,"78":6.0,"79":5.7,"80":5.5,"81":5.5,"82":5.8,"83":6.0,"84":5.4,"85":6.0,"86":6.7,"87":6.3,"88":5.6,"89":5.5,"90":5.5,"91":6.1,"92":5.8,"93":5.0,"94":5.6,"95":5.7,"96":5.7,"97":6.2,"98":5.1,"99":5.7,"100":6.3,"101":5.8,"102":7.1,"103":6.3,"104":6.5,"105":7.6,"106":4.9,"107":7.3,"108":6.7,
# ...

# %%
s='''dfjh'''

# %%
type(o)
# Out:
# str

# %%
json.loads(o)
# Out:
# {'sepal_length': {'0': 5.1,
#   '1': 4.9,
#   '2': 4.7,
#   '3': 4.6,
#   '4': 5.0,
#   '5': 5.4,
#   '6': 4.6,
#   '7': 5.0,
#   '8': 4.4,
#   '9': 4.9,
#   '10': 5.4,
#   '11': 4.8,
#   '12': 4.8,
#   '13': 4.3,
#   '14': 5.8,
#   '15': 5.7,
#   '16': 5.4,
#   '17': 5.1,
#   '18': 5.7,
#   '19': 5.1,
#   '20': 5.4,
#   '21': 5.1,
#   '22': 4.6,
#   '23': 5.1,
#   '24': 4.8,
#   '25': 5.0,
#   '26': 5.0,
#   '27': 5.2,
#   '28': 5.2,
#   '29': 4.7,
#   '30': 4.8,
#   '31': 5.4,
#   '32': 5.2,
#   '33': 5.5,
#   '34': 4.9,
#   '35': 5.0,
#   '36': 5.5,
#   '37': 4.9,
#   '38': 4.4,
#   '39': 5.1,
#   '40': 5.0,
#   '41': 4.5,
#   '42': 4.4,
#   '43': 5.0,
#   '44': 5.1,
#   '45': 4.8,
#   '46': 5.1,
#   '47': 4.6,
#   '48': 5.3,
#   '49': 5.0,
#   '50': 7.0,
#   '51': 6.4,
#   '52': 6.9,
#   '53': 5.5,
#   '54': 6.5,
#   '55': 5.7,
#   '56': 6.3,
#   '57': 4.9,
#   '58': 6.6,
#   '59': 5.2,
#   '60': 5.0,
#   '61': 5.9,
#   '62': 6.0,
#   '63': 6.1,
#   '64': 5.6,
#   '65': 6.7,
# ...

# %%
type(s)
# Out:
# str

# %%
o
# Out:
# '{ "firstName": "Joe",\n   "lastName": "Jackson",\n   "gender": "male",\n   "age": "28",\n   "address": [\n       "streetAddress", "101",\n       "city", "San Diego",\n       "state","dd"\n       ],\n   "phoneNumbers": [\n     "type", "home", "number","7349282382" ,"87","96"\n   ]\n}'

# %%
o
# Out:
# '{ "firstName": "Joe",\n   "lastName": "Jackson",\n   "gender": "male",\n   "age": "28",\n   "address": [\n       "streetAddress", "101",\n       "city", "San Diego",\n       "state","dd"\n       ],\n   "phoneNumbers": [\n     "type", "home", "number","7349282382" ,"87","96"\n   ]\n}'

# %%
type(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 type(data)
#
# NameError: name 'data' is not defined

# %%
type(o)
# Out:
# str

# %%
import json

# %%
data=json.loads(o)

# %%
pd.DataFrame(data
            )
# Out:
#   firstName lastName gender age        address phoneNumbers
# 0       Joe  Jackson   male  28  streetAddress         type
# 1       Joe  Jackson   male  28            101         home
# 2       Joe  Jackson   male  28           city       number
# 3       Joe  Jackson   male  28      San Diego   7349282382
# 4       Joe  Jackson   male  28          state           87
# 5       Joe  Jackson   male  28             dd           96

# %%
data['address']
# Out:
# ['streetAddress', '101', 'city', 'San Diego', 'state', 'dd']

# %%
del data['age']

# %%
data
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'address': ['streetAddress', '101', 'city', 'San Diego', 'state', 'dd'],
#  'phoneNumbers': ['type', 'home', 'number', '7349282382', '87', '96']}

# %%
json.loads(it converts the string to dict)
# Out:
#   Input In [28]
#     json.loads(it converts the string to dict)
#                   ^
# SyntaxError: invalid syntax

# %%
strr="""{"key":"65"}"""

# %%
strr
# Out:
# '{"key":"65"}'

# %%
json.loads(strr)
# Out:
# {'key': '65'}

# %%
type(json.loads(strr))
# Out:
# dict

# %%
import requests

# %%
data=requests.get('https://filesamples.com/samples/code/json/sample2.json')

# %%
data
# Out:
# <Response [200]>

# %%
d=data

# %%
d
# Out:
# <Response [200]>

# %%
type(data)
# Out:
# requests.models.Response

# %%
data.json()
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': 28,
#  'address': {'streetAddress': '101', 'city': 'San Diego', 'state': 'CA'},
#  'phoneNumbers': [{'type': 'home', 'number': '7349282382'}]}

# %%
data1=data.json()

# %%
type(data1)
# Out:
# dict

# %%
p="""{ "firstName": "Joe",
   "lastName": "Jackson",
   "gender": "male",
   "age": "28",
   "address": [
       "streetAddress", "101",
       "city", "San Diego",
       "state","dd"
       ],
   "phoneNumbers": [
     "type", "home", "number","7349282382" ,"87","96"
   ]
}"""

# %%
q=json.loads(p)

# %%
q
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': '28',
#  'address': ['streetAddress', '101', 'city', 'San Diego', 'state', 'dd'],
#  'phoneNumbers': ['type', 'home', 'number', '7349282382', '87', '96']}

# %%
pd.DataFrame(q['phoneNumbers'])
# Out:
#             0
# 0        type
# 1        home
# 2      number
# 3  7349282382
# 4          87
# 5          96

# %%
pd.DataFrame(q)
# Out:
#   firstName lastName gender age        address phoneNumbers
# 0       Joe  Jackson   male  28  streetAddress         type
# 1       Joe  Jackson   male  28            101         home
# 2       Joe  Jackson   male  28           city       number
# 3       Joe  Jackson   male  28      San Diego   7349282382
# 4       Joe  Jackson   male  28          state           87
# 5       Joe  Jackson   male  28             dd           96

# %%
data.json()
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': 28,
#  'address': {'streetAddress': '101', 'city': 'San Diego', 'state': 'CA'},
#  'phoneNumbers': [{'type': 'home', 'number': '7349282382'}]}

# %%
url='https://raw.githubusercontent.com/aavail/ai-workflow-capstone/master/cs-train/invoices-2017-11.json'

# %%
import requests
data=requests.get(url)

# %%
data1=data.json()

# %%
len(data1)
# Out:
# 9502

# %%
type(data1[0])
# Out:
# dict

# %%
data1[1]
# Out:
# {'country': 'United Kingdom',
#  'customer_id': None,
#  'invoice': '489597',
#  'price': 8.65,
#  'stream_id': '22130',
#  'times_viewed': 1,
#  'year': '2017',
#  'month': '11',
#  'day': '28'}

# %%
type(data.json())
# Out:
# list

# %%
data.json()
# Out:
# [{'country': 'United Kingdom',
#   'customer_id': 13085.0,
#   'invoice': '489434',
#   'price': 6.95,
#   'stream_id': '85048',
#   'times_viewed': 12,
#   'year': '2017',
#   'month': '11',
#   'day': '28'},
#  {'country': 'United Kingdom',
#   'customer_id': None,
#   'invoice': '489597',
#   'price': 8.65,
#   'stream_id': '22130',
#   'times_viewed': 1,
#   'year': '2017',
#   'month': '11',
#   'day': '28'},
#  {'country': 'United Kingdom',
#   'customer_id': None,
#   'invoice': '489597',
#   'price': 1.7,
#   'stream_id': '22132',
#   'times_viewed': 6,
#   'year': '2017',
#   'month': '11',
#   'day': '28'},
#  {'country': 'United Kingdom',
#   'customer_id': None,
#   'invoice': '489597',
#   'price': 1.7,
#   'stream_id': '22133',
#   'times_viewed': 4,
#   'year': '2017',
#   'month': '11',
#   'day': '28'},
#  {'country': 'United Kingdom',
#   'customer_id': None,
#   'invoice': '489597',
#   'price': 0.87,
#   'stream_id': '22134',
#   'times_viewed': 1,
# ...

# %%
pd.DataFrame(data1)
# Out:
#              country  customer_id invoice  price stream_id  times_viewed  \
# 0     United Kingdom      13085.0  489434   6.95     85048            12
# 1     United Kingdom          NaN  489597   8.65     22130             1
# 2     United Kingdom          NaN  489597   1.70     22132             6
# 3     United Kingdom          NaN  489597   1.70     22133             4
# 4     United Kingdom          NaN  489597   0.87     22134             1
# ...              ...          ...     ...    ...       ...           ...
# 9497  United Kingdom      13895.0  490052   1.25     21791            16
# 9498  United Kingdom      16779.0  490048   2.10     85173             6
# 9499  United Kingdom      13895.0  490052   3.75     21888             8
# 9500  United Kingdom      13895.0  490052   0.42     21917             1
# 9501  United Kingdom      13895.0  490052   0.85     21790            16
#
#       year month day
# 0     2017    11  28
# 1     2017    11  28
# 2     2017    11  28
# ...

# %%
d={'key1':255}

# %%
pd.DataFrame(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 pd.DataFrame(d)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
# ...

# %%
l1=[]
for i in data1[0]:
    l1.append([i,data1[0][i]])

# %%
l1
# Out:
# [['country', 'United Kingdom'],
#  ['customer_id', 13085.0],
#  ['invoice', '489434'],
#  ['price', 6.95],
#  ['stream_id', '85048'],
#  ['times_viewed', 12],
#  ['year', '2017'],
#  ['month', '11'],
#  ['day', '28']]

# %%
p="""{'firstName': 'Joe',
 'lastName': 'Jackson',
 'gender': 'male',
 'age': '28',
 'address': ['streetAddress', '101', 'city', 'San Diego', 'state', 'dd'],
 'phoneNumbers': ['type', 'home', 'number', '7349282382', '87', '96']}"""

# %%
json.loads(p)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 json.loads(p)
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
# ...

# %%
p="""{ "firstName": "Joe",
   "lastName": "Jackson",
   "gender": "male",
   "age": "28",
   "address": [
       "streetAddress", "101",
       "city", "San Diego",
       "state","ddf"
       ],
   "phoneNumbers": [
     "type", "home", "number","7349282382" ,"87","98"
   ]
}"""

# %%
p1=json.loads(p)

# %%
pd.DataFrame(p1)
# Out:
#   firstName lastName gender age        address phoneNumbers
# 0       Joe  Jackson   male  28  streetAddress         type
# 1       Joe  Jackson   male  28            101         home
# 2       Joe  Jackson   male  28           city       number
# 3       Joe  Jackson   male  28      San Diego   7349282382
# 4       Joe  Jackson   male  28          state           87
# 5       Joe  Jackson   male  28            ddf           98

# %%
import requests

# %%
url='https://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/students.json'

# %%
data=requests.get(url)

# %%
data.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
data.encoding

# %%
data2=data.json()

# %%
data1

# %%
df=pd.read_csv(r'C:\Users\91986\Documents\mu_sigma\mu_sigma\Problem statement 1_dataset/adult.csv')

# %%
df.isnull().sum()

# %%
df

# %%
df['education'].value_counts()

# %%
df['education'].value_counts()

# %%
df.info()

# %%
df.describe()

# %%
len(df[df['age']==max(df['age'])])
# Out:
# 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   firstName     6 non-null      object
#  1   lastName      6 non-null      object
#  2   gender        6 non-null      object
#  3   age           6 non-null      int64
#  4   address       6 non-null      object
#  5   phoneNumbers  6 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 416.0+ bytes

# %%
df
# Out:
#   firstName lastName gender  age        address phoneNumbers
# 0       Joe  Jackson   male   28  streetAddress         type
# 1       Joe  Jackson   male   28            101         home
# 2       Joe  Jackson   male   28           city       number
# 3       Joe  Jackson   male   28      San Diego   7349282382
# 4       Joe  Jackson   male   28          state           87
# 5       Joe  Jackson   male   28             dd           96

# %%
url='https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# %%
data=requests.get(url)

# %%
import requests

# %%
df1=pd.read_csv(url)

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
url='https://raw.githubusercontent.com/thephpleague/csv/master/composer.json'

# %%
data=requests.get(url)

# %%
data.json()
# Out:
# {'name': 'league/csv',
#  'type': 'library',
#  'description': 'CSV data manipulation made easy in PHP',
#  'keywords': ['csv',
#   'import',
#   'export',
#   'read',
#   'write',
#   'filter',
#   'convert',
#   'transform'],
#  'license': 'MIT',
#  'homepage': 'https://csv.thephpleague.com',
#  'authors': [{'name': 'Ignace Nyamagana Butera',
#    'email': 'nyamsprod@gmail.com',
#    'homepage': 'https://github.com/nyamsprod/',
#    'role': 'Developer'}],
#  'support': {'docs': 'https://csv.thephpleague.com',
#   'issues': 'https://github.com/thephpleague/csv/issues',
#   'rss': 'https://github.com/thephpleague/csv/releases.atom',
#   'source': 'https://github.com/thephpleague/csv'},
#  'funding': [{'type': 'github',
#    'url': 'https://github.com/sponsors/nyamsprod'}],
#  'require': {'php': '^8.1.2', 'ext-json': '*', 'ext-mbstring': '*'},
#  'require-dev': {'ext-dom': '*',
#   'doctrine/collections': '^1.6.8',
#   'friendsofphp/php-cs-fixer': '^v3.9',
# ...

# %%
df1.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df1.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in df1.columns:
    print(i)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1[['Age','Cabin','Embarked']]
# Out:
#       Age Cabin Embarked
# 0    22.0   NaN        S
# 1    38.0   C85        C
# 2    26.0   NaN        S
# 3    35.0  C123        S
# 4    35.0   NaN        S
# ..    ...   ...      ...
# 886  27.0   NaN        S
# 887  19.0   B42        S
# 888   NaN   NaN        S
# 889  26.0  C148        C
# 890  32.0   NaN        Q
#
# [891 rows x 3 columns]

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe()
# Out:
#         age
# count   6.0
# mean   28.0
# std     0.0
# min    28.0
# 25%    28.0
# 50%    28.0
# 75%    28.0
# max    28.0

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
l=[4,5,6,4,5,6,'sudf','jffj']

# %%
l[l=='sudf']
# Out:
# 4

# %%
col_name=df1.dtypes[df1.dtypes == 'object'].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df1[col_name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df1[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1['New_column']='Ineuron'

# %%
df1['Name'][0:20:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# 16                                 Rice, Master. Eugene
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...
# Name: Name, dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  New_column   891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
df1[df1['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df1[df1['Cabin'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
len(df1[df1['Age'].isnull() == True].index)
# Out:
# 177

# %%
df1[df1['Age'].isnull() ==True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ind=df1[df1['Age'].isnull() == True]

# %%
ind1=df1[df1['Age'].isnull() == True].index

# %%
ind1
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
df1.loc[ind1]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df1[df1['Fare'] == max(df1['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df1['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df1[df1['Sex'].str.startswith('f')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df
# Out:
#   firstName lastName gender  age        address phoneNumbers
# 0       Joe  Jackson   male   28  streetAddress         type
# 1       Joe  Jackson   male   28            101         home
# 2       Joe  Jackson   male   28           city       number
# 3       Joe  Jackson   male   28      San Diego   7349282382
# 4       Joe  Jackson   male   28          state           87
# 5       Joe  Jackson   male   28             dd           96

# %%
df
# Out:
#   firstName lastName gender  age        address phoneNumbers
# 0       Joe  Jackson   male   28  streetAddress         type
# 1       Joe  Jackson   male   28            101         home
# 2       Joe  Jackson   male   28           city       number
# 3       Joe  Jackson   male   28      San Diego   7349282382
# 4       Joe  Jackson   male   28          state           87
# 5       Joe  Jackson   male   28             dd           96

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1[df1.dtypes[df1.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked New_column
# 0           A/5 21171   NaN        S    Ineuron
# 1            PC 17599   C85        C    Ineuron
# 2    STON/O2. 3101282   NaN        S    Ineuron
# ...

# %%
df
# Out:
#   firstName lastName gender  age        address phoneNumbers
# 0       Joe  Jackson   male   28  streetAddress         type
# 1       Joe  Jackson   male   28            101         home
# 2       Joe  Jackson   male   28           city       number
# 3       Joe  Jackson   male   28      San Diego   7349282382
# 4       Joe  Jackson   male   28          state           87
# 5       Joe  Jackson   male   28             dd           96

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
name=df1.dtypes[df1.dtypes=='object'].index

# %%
df1[df1.dtypes[df1.dtypes =='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked New_column
# 0           A/5 21171   NaN        S    Ineuron
# 1            PC 17599   C85        C    Ineuron
# 2    STON/O2. 3101282   NaN        S    Ineuron
# ...

# %%
name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'New_column'], dtype='object')

# %%
df1[df1.dtypes[df1.dtypes=='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked New_column
# 0           A/5 21171   NaN        S    Ineuron
# 1            PC 17599   C85        C    Ineuron
# 2    STON/O2. 3101282   NaN        S    Ineuron
# ...

# %%
df1[name]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked New_column
# 0           A/5 21171   NaN        S    Ineuron
# 1            PC 17599   C85        C    Ineuron
# 2    STON/O2. 3101282   NaN        S    Ineuron
# ...

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.Age[df1.Age == '22']
# Out:
# Series([], Name: Age, dtype: float64)

# %%
df1['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# New_column      object
# dtype: object

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'New_column'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  New_column   891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ind=df1[df1['Age'].isnull() == True].index

# %%
df1.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  New_column   891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
col=df1[df1['Cabin'].isnull() == True].index

# %%
df1.loc[col]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  New_column   891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
df1[df1['Sex'].str.startswith('m')== True]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked New_column
# ...

# %%
df1[df1['Sex'].str.startswith('f')== True]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df1['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df1['Pclass'].value_counts()[::-1]
# Out:
# 2    184
# 1    216
# 3    491
# Name: Pclass, dtype: int64

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
max(df1['Fare'])
# Out:
# 512.3292

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df1['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df1['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(df1[df1['Sex'] == 'male'])
# Out:
# 577

# %%
len(df1[df1['Sex'] == 'female'])
# Out:
# 314

# %%
df1.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
df1[df1['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked New_column
# ...

# %%
df1['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df1.groupby('Survived')['Survived'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
len(df1[df1['Survived'] == 0])
# Out:
# 549

# %%
len(df1[df1['Age']>60])
# Out:
# 22

# %%
len(df1[df1['Survived'] == 0])
# Out:
# 549

# %%
df1[df1['Age'] == max(df1['Age'])]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df1['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df1.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
len(df1[df1['Name'].str.startswith('S')][['Name','Age']])
# Out:
# 86

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1['summ']=df1['SibSp']+df1['Parch']

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df1[df1['Age'] < 25])
# Out:
# 278

# %%
df1[(df1['Age']<40) & (df1['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 4              5         0       3              Allen, Mr. William Henry
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 12            13         0       3        Saundercock, Mr. William Henry
# 13            14         0       3           Andersson, Mr. Anders Johan
# ..           ...       ...     ...                                   ...
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                 Montvila, Rev. Juozas
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  \
# ...

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()
# Out:
#   firstName lastName gender  age        address phoneNumbers
# 0       Joe  Jackson   male   28  streetAddress         type
# 1       Joe  Jackson   male   28            101         home
# 2       Joe  Jackson   male   28           city       number
# 3       Joe  Jackson   male   28      San Diego   7349282382
# 4       Joe  Jackson   male   28          state           87
# 5       Joe  Jackson   male   28             dd           96

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data=requests.get('https://filesamples.com/samples/code/json/sample2.json')

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
pd.read_json('https://filesamples.com/samples/code/json/sample2.json')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [190], in <cell line: 1>()
# ----> 1 pd.read_json('https://filesamples.com/samples/code/json/sample2.json')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
data=requests.get('https://filesamples.com/samples/code/json/sample2.json')

# %%
data1=data.json()

# %%
data1
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': 28,
#  'address': {'streetAddress': '101', 'city': 'San Diego', 'state': 'CA'},
#  'phoneNumbers': [{'type': 'home', 'number': '7349282382'}]}

# %%
data1['phoneNumbers'][0]['number']
# Out:
# '7349282382'

# %%
k="""{
    "khan":88892410769,
    "key1":256,
    "key2":4563
    
    
    
}"""

# %%
type(k)
# Out:
# str

# %%
import json

# %%
json.loads(k)
# Out:
# {'khan': 88892410769, 'key1': 256, 'key2': 4563}

# %%
p="""{ "firstName": "Joe",
   "lastName": "Jackson",
   "gender": "male",
   "age": "28",
   "address": [
       "streetAddress", "101",
       "city", "San Diego",
       "state","ddf"
       ],
   "phoneNumbers": [
     "type", "home", "number","7349282382" ,"87","98"
   ]
}"""

# %%
json.loads(p)
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': '28',
#  'address': ['streetAddress', '101', 'city', 'San Diego', 'state', 'ddf'],
#  'phoneNumbers': ['type', 'home', 'number', '7349282382', '87', '98']}

# %%
k
# Out:
# '{\n    "khan":88892410769,\n    "key1":256,\n    "key2":4563\n    \n    \n    \n}'

# %%
p
# Out:
# '{ "firstName": "Joe",\n   "lastName": "Jackson",\n   "gender": "male",\n   "age": "28",\n   "address": [\n       "streetAddress", "101",\n       "city", "San Diego",\n       "state","ddf"\n       ],\n   "phoneNumbers": [\n     "type", "home", "number","7349282382" ,"87","98"\n   ]\n}'

# %%
type(k)
# Out:
# str

# %%
type(p)
# Out:
# str

# %%
k
# Out:
# '{\n    "khan":88892410769,\n    "key1":256,\n    "key2":4563\n    \n    \n    \n}'

# %%
p
# Out:
# '{ "firstName": "Joe",\n   "lastName": "Jackson",\n   "gender": "male",\n   "age": "28",\n   "address": [\n       "streetAddress", "101",\n       "city", "San Diego",\n       "state","ddf"\n       ],\n   "phoneNumbers": [\n     "type", "home", "number","7349282382" ,"87","98"\n   ]\n}'

# %%
json.loads(k)
# Out:
# {'khan': 88892410769, 'key1': 256, 'key2': 4563}

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ind=df1[df1['Age']==4].index

# %%
df1.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 10            11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 445          446         1       1        Dodge, Master. Washington    male
# 618          619         1       2      Becker, Miss. Marion Louise  female
#
#      Age  SibSp  Parch   Ticket     Fare Cabin Embarked New_column  summ
# 10   4.0      1      1  PP 9549  16.7000    G6        S    Ineuron     2
# 445  4.0      0      2    33638  81.8583   A34        S    Ineuron     2
# 618  4.0      2      1   230136  39.0000    F4        S    Ineuron     3

# %%
df1.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
ind
# Out:
# Int64Index([10, 445, 618], dtype='int64')

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# !pip install cufflinks
# !pip install plotly
import plotly as py
import plotly.express as px
from plotly.offline import iplot
import plotly.tools as tl
import cufflinks as cf
# Out:
# ...
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ymongo (c:\users\91986\anaconda3\lib\site-packages)
# ...

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
px.box(x)
# Out:
# <div>                            <div id="fe81f291-7d84-41ae-b818-e10fd6b7a4da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe81f291-7d84-41ae-b818-e10fd6b7a4da")) {                    Plotly.newPlot(                        "fe81f291-7d84-41ae-b818-e10fd6b7a4da",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["0","0","0","0","0","0","0"],"x0":" ","xaxis":"x","y":[1,23,40,50,60,70,1000],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"colo
# ...

# %%
x=[1,23,40,50,60,70,1000]
y=[20,40,60,80,70,80,90]

# %%
px.line(x,y)
# Out:
# <div>                            <div id="e115c0bc-119b-44d9-bd2a-e132300b8de2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e115c0bc-119b-44d9-bd2a-e132300b8de2")) {                    Plotly.newPlot(                        "e115c0bc-119b-44d9-bd2a-e132300b8de2",                        [{"hovertemplate":"x=%{x}<br>index=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[20,40,60,80,70,80,90],"xaxis":"x","y":[0,1,2,3,4,5,6],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":
# ...

# %%
px.histogram(x)
# Out:
# <div>                            <div id="420646b9-b998-4286-8318-1d195d92e946" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("420646b9-b998-4286-8318-1d195d92e946")) {                    Plotly.newPlot(                        "420646b9-b998-4286-8318-1d195d92e946",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=0<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[1,23,40,50,60,70,1000],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6
# ...

# %%
df = pd.DataFrame({'player': ['A', '54', '70', '540', '80'],
                   'points': ['25', '27', '14', '17', '20'],
                   'assists': ['5', '7', '10', '8', '9']})

# %%
df
# Out:
#   player points assists
# 0      A     25       5
# 1     54     27       7
# 2     70     14      10
# 3    540     17       8
# 4     80     20       9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   player   5 non-null      object
#  1   points   5 non-null      object
#  2   assists  5 non-null      object
# dtypes: object(3)
# memory usage: 248.0+ bytes

# %%
df.describe()
# Out:
#        player points assists
# count       5      5       5
# unique      5      5       5
# top         A     25       5
# freq        1      1       1

# %%
df.dtypes
# Out:
# player     object
# points     object
# assists    object
# dtype: object

# %%
df['assists']=df['assists'].astype(int).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   player   5 non-null      object
#  1   points   5 non-null      object
#  2   assists  5 non-null      int32
# dtypes: int32(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#          assists
# count   5.000000
# mean    7.800000
# std     1.923538
# min     5.000000
# 25%     7.000000
# 50%     8.000000
# 75%     9.000000
# max    10.000000

# %%
df
# Out:
#   player points  assists
# 0      A     25        5
# 1     54     27        7
# 2     70     14       10
# 3    540     17        8
# 4     80     20        9

# %%
df.dtypes
# Out:
# player     object
# points     object
# assists     int32
# dtype: object

# %%
df['player']=df['player'].astype(int).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [174], in <cell line: 1>()
# ----> 1 df['player']=df['player'].astype(int).astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   player   5 non-null      object
#  1   points   5 non-null      int32
#  2   assists  5 non-null      int32
# dtypes: int32(2), object(1)
# memory usage: 208.0+ bytes

# %%
val=df.dtypes[df.dtypes == 'int'].index

# %%
df[val]
# Out:
#    points  assists
# 0      25        5
# 1      27        7
# 2      14       10
# 3      17        8
# 4      20        9

# %%
df.loc[df['points']>14]
# Out:
#   player  points  assists
# 0      A      25        5
# 1     54      27        7
# 3    540      17        8
# 4     80      20        9

# %%
df[df['points']>14]
# Out:
#   player  points  assists
# 0      A      25        5
# 1     54      27        7
# 3    540      17        8
# 4     80      20        9

# %%
import seaborn as sn

# %%
df=sn.load_dataset('iris')

# %%
df.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN
